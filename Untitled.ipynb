# %%
from utils import resize
from segmentation import segmentation
from colorCorrection import colorCorrection
from prediction import Predict
import matplotlib.pyplot as plt
from matplotlib.image import imread
import framework
import tensorflow as tf
from PIL import Image
import warnings
warnings.filterwarnings('ignore')

def __main__():
    print("Environment 3")
    path = "./image/env3.jpg"
    img = Image.open(path)
    framework.predict(path,"./utils/ref-env3.csv","./utils/reference2.csv")
    
__main__()
# Out:
# Environment 3
# Runtime of cc is 0.9726541042327881
# Loaded model from disk
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x15add3b70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Runtime of segmentation is 7.206873893737793
# Runtime of classification is 4.36503791809082
# ...
# RESULT
# ...

# %%
### from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

#before_first_cond
# data1 = [50.583407513665996, 24.47674414356127, 9.804712102097767]
# data2 = [39.018936380741046, 22.693607654955233, 12.51868593483919]
# data3 = [52.66469118389345, 16.07796710415965, 14.718634170149514]

# before_sec_cond
data1 = [61.25116758428946, 19.553170864578195, -1.5042801267949324]
data2 = [58.95311788484884, 20.460108923306326, 3.9470628788820905]
data3 = [32.985058573475094, 34.16575341568967, 13.886771022610755]

# data1 = [43.0105845,  28.14798838, 16.90241779]
# data2 = [46.18362712, 31.84179356, 18.37942712]
# data3 = [46.60066014, 33.29879143, 15.33745665]

#after_first_cond
# data1 = [47.54, 34.73, 13.83]
# data2 = [45.82, 34.99, 17.38]
# data3 = [47.17, 34.67, 20.71]

#after_sec_cond
# data1 = [43.11287070329603, 32.827425385831944, 10.178173344637543]
# data2 = [43.4293334371157, 33.223141699024964, 12.317107513637948]
# data3 = [37.4247368461446, 36.59662472471265, 18.53443210560044]
# Creating figure
fig = plt.figure(figsize = (5.2, 5))
ax = plt.axes(projection ="3d")
plt.xlim(xmin=0,xmax=100)
plt.ylim(ymin=0,ymax=70)
ax.set_zlim(-50,50)
# Creating plot
ax.scatter3D(data1[0],data1[1],data1[2], color = "green",label="Env1",  s=60)
ax.scatter3D(data2[0],data2[1],data2[2], color = "orange",label="Env2",  s=60)
ax.scatter3D(data3[0],data3[1],data3[2], color = "blue",label="Env3",  s=60)
ax.legend()
plt.title("Result Before Prediction")
 
# show plot
plt.show()

# %% [markdown]
# #####

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
 
# data1 = [47.91, 28.34, 12.65]
# data2 = [40.10, 22.69, 12.35]
# data3 = [48.04, 17.60, 10.18]


data1 = [47.79, 31.59, 11.30]
data2 = [40.33, 30.82, 11.73]
data3 = [48.04, 17.60, 10.18]
# Creating figure
fig = plt.figure(figsize = (5.2, 4.5))
ax = plt.axes(projection ="3d")
plt.xlim(xmin=0,xmax=100)
plt.ylim(ymin=0,ymax=70)
ax.set_zlim(-50,50)
# Creating plot
ax.scatter3D(data1[0],data1[1],data1[2], color = "green",label="Env1",  s=60)
ax.scatter3D(data2[0],data2[1],data2[2], color = "orange",label="Env2",  s=60)
ax.scatter3D(data3[0],data3[1],data3[2], color = "blue",label="Env3",  s=60)
ax.legend()
plt.title("Result Before Prediction")
 
# show plot
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:16: MatplotlibDeprecationWarning:
# The `xmin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `left` instead.
#   app.launch_new_instance()
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:16: MatplotlibDeprecationWarning:
# The `xmax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `right` instead.
#   app.launch_new_instance()
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:17: MatplotlibDeprecationWarning:
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:17: MatplotlibDeprecationWarning:
# ...

# %%
data1 = [58.95311788484884, 20.460108923306326, 3.9470628788820905]
data2 = [32.985058573475094, 34.16575341568967, 13.886771022610755]
print(((data1[0] - data2[0])**2 + (data1[1] - data2[1])**2 + (data1[2] - data2[2])**2)**(0.5))
# Out:
# 30.999719246037188
